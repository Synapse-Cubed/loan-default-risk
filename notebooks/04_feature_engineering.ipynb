# %% [markdown]
# # Feature Enginerring
# - engineer more features
# - aggregate repayment_history
# - merge final table
# - save table ready for machine and neural network

# %% [markdown]
# ### Data Aggregation
# since it has multiple records to one customer and the dataset is mostly/all about customer with repeated loan takes
# one to many relationship

# %%
# Import Libraries 
import pandas as pd

# %%
# Load the cleaned datasets
df1 = pd.read_csv(r"C:\Users\USER\my_workspace\synapse\loan-default-risk\data\interim\loan_applications.csv")
df2 = pd.read_csv(r"C:\Users\USER\my_workspace\synapse\loan-default-risk\data\interim/customer_banking_profile.csv")
df3 = pd.read_csv(r"C:\Users\USER\my_workspace\synapse\loan-default-risk\data\interim/repayment_history.csv")
