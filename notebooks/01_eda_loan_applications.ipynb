# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Define file path and import dataset
url1 = "C:/Users/USER/my_workspace/synapse/loan-default-risk/kdata/raw/loan_applications"
df1 = pd.read_csv(url1)
print(df1)
